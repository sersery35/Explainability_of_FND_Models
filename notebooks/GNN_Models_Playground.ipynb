# %%
% load_ext autoreload
% autoreload 2

# %%
from Explainability_of_FND_Models.models.gnn_models import bigcn, gcnfn, gnn, gnncl
from Explainability_of_FND_Models.utils.gnn_utils.helpers import *

# %%
def run_model(model_type: GNNModelTypeEnum):
    """
    method is a convenient wrapper to initialize, train then evaluate the model
    """
    args = ModelArguments()
    hparams = HparamManager(model_type)
    dataset_manager = GNNDatasetManager(hparams, multi_gpu=args.multi_gpu)
    if model_type == GNNModelTypeEnum.BIGCN:
        model = bigcn.BiGCNet(model_args=args,
                              model_hparams=hparams,
                              model_dataset_manager=dataset_manager)
    elif model_type in [GNNModelTypeEnum.UPFD_GCNFN, GNNModelTypeEnum.VANILLA_GCNFN]:
        model = gcnfn.GCNFNet(model_args=args,
                              model_hparams=hparams,
                              model_dataset_manager=dataset_manager)
    elif model_type in [GNNModelTypeEnum.GCN_GNN, GNNModelTypeEnum.GAT_GNN, GNNModelTypeEnum.SAGE_GNN]:
        model = gnn.GNNet(model_args=args,
                          model_hparams=hparams,
                          model_dataset_manager=dataset_manager)
    elif model_type == GNNModelTypeEnum.GNNCL:
        model = gnncl.GNNCLNet(model_args=args,
                               model_hparams=hparams,
                               model_dataset_manager=dataset_manager)
    else:
        raise ValueError(f'Options are {GNNModelTypeEnum.all_elements()}')

    model.train_then_eval()

# %% [markdown]
# # 1. Explain Bi-GCN

# %%
run_model(GNNModelTypeEnum.BIGCN)
# Out:
# Loading data from directory: /home/sersery/Desktop/TUM_Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data
#
# ************** epoch: 0 **************
# loss_train: 0.7085, acc_train: 0.2419,
# recall_train: 0.3077, auc_train: 0.1538,
# loss_val: 0.8737, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4060
# ***************************************
#
# ************** epoch: 1 **************
# loss_train: 0.7039, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5150,
# loss_val: 0.6614, acc_val: 0.7419,
# recall_val: 0.7222, auc_val: 0.7393
# ***************************************
#
# ************** epoch: 2 **************
# loss_train: 0.6291, acc_train: 0.8226,
# recall_train: 0.6154, auc_train: 0.8408,
# loss_val: 0.6162, acc_val: 0.6774,
# recall_val: 0.8889, auc_val: 0.7179
# ***************************************
#
# ************** epoch: 3 **************
# loss_train: 0.6248, acc_train: 0.6774,
# recall_train: 0.9615, auc_train: 0.8312,
# loss_val: 0.6128, acc_val: 0.7419,
# recall_val: 0.8333, auc_val: 0.7350
# ***************************************
#
# ************** epoch: 4 **************
# loss_train: 0.5831, acc_train: 0.7742,
# recall_train: 0.7308, auc_train: 0.8483,
# loss_val: 0.6738, acc_val: 0.5806,
# recall_val: 0.3889, auc_val: 0.7179
# ***************************************
#
# ************** epoch: 5 **************
# loss_train: 0.5578, acc_train: 0.7258,
# recall_train: 0.3846, auc_train: 0.8526,
# loss_val: 0.7053, acc_val: 0.4839,
# recall_val: 0.2222, auc_val: 0.7222
# ***************************************
#
# ************** epoch: 6 **************
# loss_train: 0.5397, acc_train: 0.7419,
# recall_train: 0.4231, auc_train: 0.8675,
# loss_val: 0.6605, acc_val: 0.6452,
# recall_val: 0.5000, auc_val: 0.7308
# ***************************************
#
# ************** epoch: 7 **************
# loss_train: 0.5160, acc_train: 0.7903,
# recall_train: 0.5385, auc_train: 0.8707,
# loss_val: 0.5940, acc_val: 0.7742,
# recall_val: 0.8333, auc_val: 0.7521
# ***************************************
#
# ************** epoch: 8 **************
# loss_train: 0.4933, acc_train: 0.8226,
# recall_train: 0.7308, auc_train: 0.8718,
# loss_val: 0.6266, acc_val: 0.7419,
# recall_val: 0.8333, auc_val: 0.7308
# ***************************************
#
# ************** epoch: 9 **************
# loss_train: 0.4881, acc_train: 0.7903,
# recall_train: 0.7308, auc_train: 0.8739,
# loss_val: 0.5999, acc_val: 0.7097,
# recall_val: 0.7222, auc_val: 0.7479
# ***************************************
#
# ************** epoch: 10 **************
# loss_train: 0.4453, acc_train: 0.8387,
# recall_train: 0.7308, auc_train: 0.8964,
# loss_val: 0.6350, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.7436
# ***************************************
#
# ************** epoch: 11 **************
# loss_train: 0.4236, acc_train: 0.8548,
# recall_train: 0.6923, auc_train: 0.9028,
# loss_val: 0.6107, acc_val: 0.7742,
# recall_val: 0.7778, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 12 **************
# loss_train: 0.4069, acc_train: 0.8710,
# recall_train: 0.7308, auc_train: 0.9049,
# loss_val: 0.5578, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 13 **************
# loss_train: 0.3838, acc_train: 0.8387,
# recall_train: 0.7308, auc_train: 0.9177,
# loss_val: 0.6008, acc_val: 0.7419,
# recall_val: 0.7778, auc_val: 0.7692
# ***************************************
#
# ************** epoch: 14 **************
# loss_train: 0.3534, acc_train: 0.8387,
# recall_train: 0.8077, auc_train: 0.9380,
# loss_val: 0.6330, acc_val: 0.8065,
# recall_val: 0.7778, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 15 **************
# loss_train: 0.3452, acc_train: 0.8548,
# recall_train: 0.7692, auc_train: 0.9348,
# loss_val: 0.6624, acc_val: 0.8065,
# recall_val: 0.7778, auc_val: 0.7735
# ***************************************
#
# ************** epoch: 16 **************
# loss_train: 0.3410, acc_train: 0.8226,
# recall_train: 0.6923, auc_train: 0.9380,
# loss_val: 0.6181, acc_val: 0.8065,
# recall_val: 0.7778, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 17 **************
# loss_train: 0.3305, acc_train: 0.8387,
# recall_train: 0.8077, auc_train: 0.9434,
# loss_val: 0.6276, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.7821
# ***************************************
#
# ************** epoch: 18 **************
# loss_train: 0.2983, acc_train: 0.8548,
# recall_train: 0.8462, auc_train: 0.9551,
# loss_val: 0.7971, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 19 **************
# loss_train: 0.3036, acc_train: 0.8871,
# recall_train: 0.8077, auc_train: 0.9476,
# loss_val: 0.7425, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.7735
# ***************************************
#
# ************** epoch: 20 **************
# loss_train: 0.3144, acc_train: 0.8548,
# recall_train: 0.7692, auc_train: 0.9348,
# loss_val: 0.6825, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 21 **************
# loss_train: 0.2798, acc_train: 0.8710,
# recall_train: 0.8846, auc_train: 0.9573,
# loss_val: 0.8119, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 22 **************
# loss_train: 0.2690, acc_train: 0.8710,
# recall_train: 0.8462, auc_train: 0.9594,
# loss_val: 0.9701, acc_val: 0.7097,
# recall_val: 0.6111, auc_val: 0.7735
# ***************************************
#
# ************** epoch: 23 **************
# loss_train: 0.3187, acc_train: 0.8387,
# recall_train: 0.7308, auc_train: 0.9412,
# loss_val: 0.8783, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 24 **************
# loss_train: 0.2788, acc_train: 0.8548,
# recall_train: 0.7692, auc_train: 0.9541,
# loss_val: 1.2548, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.7564
# ***************************************
#
# ************** epoch: 25 **************
# loss_train: 0.2875, acc_train: 0.8710,
# recall_train: 0.8846, auc_train: 0.9498,
# loss_val: 0.9710, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.7564
# ***************************************
#
# ************** epoch: 26 **************
# loss_train: 0.2444, acc_train: 0.8710,
# recall_train: 0.8462, auc_train: 0.9679,
# loss_val: 1.6549, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 27 **************
# loss_train: 0.2760, acc_train: 0.8548,
# recall_train: 0.7692, auc_train: 0.9530,
# loss_val: 1.0536, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.7906
# ***************************************
#
# ************** epoch: 28 **************
# loss_train: 0.2828, acc_train: 0.8548,
# recall_train: 0.7692, auc_train: 0.9541,
# loss_val: 1.5679, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.7564
# ***************************************
#
# ************** epoch: 29 **************
# loss_train: 0.2930, acc_train: 0.8710,
# recall_train: 0.8077, auc_train: 0.9487,
# loss_val: 1.4542, acc_val: 0.7742,
# recall_val: 0.7778, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 30 **************
# loss_train: 0.2776, acc_train: 0.8871,
# recall_train: 0.8462, auc_train: 0.9573,
# loss_val: 0.9923, acc_val: 0.8065,
# recall_val: 0.7778, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 31 **************
# loss_train: 0.2412, acc_train: 0.9194,
# recall_train: 0.9231, auc_train: 0.9690,
# loss_val: 1.3610, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.7949
# ***************************************
#
# ************** epoch: 32 **************
# loss_train: 0.2475, acc_train: 0.8710,
# recall_train: 0.8077, auc_train: 0.9647,
# loss_val: 1.0494, acc_val: 0.7097,
# recall_val: 0.6111, auc_val: 0.7821
# ***************************************
#
# ************** epoch: 33 **************
# loss_train: 0.2642, acc_train: 0.8710,
# recall_train: 0.7692, auc_train: 0.9583,
# loss_val: 0.9095, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.7991
# ***************************************
#
# ************** epoch: 34 **************
# loss_train: 0.2940, acc_train: 0.8548,
# recall_train: 0.7692, auc_train: 0.9476,
# loss_val: 0.8416, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8162
# ***************************************
#
# ************** epoch: 35 **************
# loss_train: 0.2850, acc_train: 0.8871,
# recall_train: 0.8462, auc_train: 0.9509,
# loss_val: 0.8046, acc_val: 0.7742,
# recall_val: 0.7778, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 36 **************
# loss_train: 0.2746, acc_train: 0.9032,
# recall_train: 0.8846, auc_train: 0.9605,
# loss_val: 0.8691, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.7949
# ***************************************
#
# ************** epoch: 37 **************
# loss_train: 0.2522, acc_train: 0.8871,
# recall_train: 0.8462, auc_train: 0.9637,
# loss_val: 1.4208, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.8120
# ***************************************
#
# ************** epoch: 38 **************
# loss_train: 0.2807, acc_train: 0.8548,
# recall_train: 0.7692, auc_train: 0.9583,
# loss_val: 0.8808, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.8077
# ***************************************
#
# ************** epoch: 39 **************
# loss_train: 0.2791, acc_train: 0.8548,
# recall_train: 0.7692, auc_train: 0.9562,
# loss_val: 0.8226, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 40 **************
# loss_train: 0.2578, acc_train: 0.9032,
# recall_train: 0.9231, auc_train: 0.9658,
# loss_val: 0.7519, acc_val: 0.7742,
# recall_val: 0.7778, auc_val: 0.8162
# ***************************************
#
# ************** epoch: 41 **************
# loss_train: 0.2446, acc_train: 0.8710,
# recall_train: 0.8846, auc_train: 0.9701,
# loss_val: 0.8465, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.8077
# ***************************************
#
# ************** epoch: 42 **************
# loss_train: 0.2357, acc_train: 0.8871,
# recall_train: 0.8462, auc_train: 0.9679,
# loss_val: 1.0060, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.7821
# ***************************************
#
# ************** epoch: 43 **************
# loss_train: 0.2638, acc_train: 0.8710,
# recall_train: 0.8077, auc_train: 0.9658,
# loss_val: 0.9122, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 44 **************
# loss_train: 0.2538, acc_train: 0.8710,
# recall_train: 0.8077, auc_train: 0.9658,
# loss_val: 0.8298, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.7991
# ***************************************
# Test set results: acc: 0.7873, f1_macro: 0.7854, f1_micro: 0.7873,precision: 0.7768, recall: 0.8252, auc: 0.8527, ap: 0.8410

# %% [markdown]
# # 2. Explain GCNFN

# %% [markdown]
# ### 2.1. UPFD-GCNFN

# %%
run_model(GNNModelTypeEnum.UPFD_GCNFN)
# Out:
# Loading data from directory: /home/sersery/Desktop/TUM_Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data
#
# ************** epoch: 0 **************
# loss_train: 0.7329, acc_train: 0.4516,
# recall_train: 0.9615, auc_train: 0.4947,
# loss_val: 3.3966, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4872
# ***************************************
#
# ************** epoch: 1 **************
# loss_train: 2.4525, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5278,
# loss_val: 3.3769, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.6368
# ***************************************
#
# ************** epoch: 2 **************
# loss_train: 4.6915, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.4941,
# loss_val: 0.7883, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4402
# ***************************************
#
# ************** epoch: 3 **************
# loss_train: 0.6952, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.4092,
# loss_val: 1.9937, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4316
# ***************************************
#
# ************** epoch: 4 **************
# loss_train: 1.4406, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5246,
# loss_val: 0.9746, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.6197
# ***************************************
#
# ************** epoch: 5 **************
# loss_train: 1.3011, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.5246,
# loss_val: 0.9011, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.4188
# ***************************************
#
# ************** epoch: 6 **************
# loss_train: 1.1873, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.3996,
# loss_val: 0.7267, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.2350
# ***************************************
#
# ************** epoch: 7 **************
# loss_train: 0.6988, acc_train: 0.5645,
# recall_train: 0.0000, auc_train: 0.1132,
# loss_val: 1.0327, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3590
# ***************************************
#
# ************** epoch: 8 **************
# loss_train: 0.8123, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.3921,
# loss_val: 0.7937, acc_val: 0.4516,
# recall_val: 0.0556, auc_val: 0.6410
# ***************************************
#
# ************** epoch: 9 **************
# loss_train: 0.6842, acc_train: 0.5806,
# recall_train: 0.0385, auc_train: 0.6357,
# loss_val: 0.6643, acc_val: 0.6129,
# recall_val: 1.0000, auc_val: 0.7607
# ***************************************
#
# ************** epoch: 10 **************
# loss_train: 0.7393, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.7179,
# loss_val: 0.6571, acc_val: 0.6129,
# recall_val: 1.0000, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 11 **************
# loss_train: 0.7291, acc_train: 0.4355,
# recall_train: 1.0000, auc_train: 0.7276,
# loss_val: 0.8204, acc_val: 0.4516,
# recall_val: 0.0556, auc_val: 0.7393
# ***************************************
#
# ************** epoch: 12 **************
# loss_train: 0.6628, acc_train: 0.5968,
# recall_train: 0.1923, auc_train: 0.7147,
# loss_val: 0.9892, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7094
# ***************************************
#
# ************** epoch: 13 **************
# loss_train: 0.7278, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7607,
# loss_val: 0.6516, acc_val: 0.5806,
# recall_val: 0.4444, auc_val: 0.7051
# ***************************************
#
# ************** epoch: 14 **************
# loss_train: 0.6027, acc_train: 0.7258,
# recall_train: 0.6923, auc_train: 0.8077,
# loss_val: 0.6252, acc_val: 0.6452,
# recall_val: 1.0000, auc_val: 0.7564
# ***************************************
#
# ************** epoch: 15 **************
# loss_train: 0.6712, acc_train: 0.5323,
# recall_train: 1.0000, auc_train: 0.8857,
# loss_val: 0.6767, acc_val: 0.4516,
# recall_val: 0.0556, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 16 **************
# loss_train: 0.5455, acc_train: 0.7742,
# recall_train: 0.5000, auc_train: 0.9113,
# loss_val: 0.9074, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 17 **************
# loss_train: 0.6072, acc_train: 0.5968,
# recall_train: 0.0385, auc_train: 0.9498,
# loss_val: 0.6313, acc_val: 0.6452,
# recall_val: 0.5556, auc_val: 0.7308
# ***************************************
#
# ************** epoch: 18 **************
# loss_train: 0.4775, acc_train: 0.8871,
# recall_train: 0.8846, auc_train: 0.9241,
# loss_val: 0.5777, acc_val: 0.7097,
# recall_val: 0.9444, auc_val: 0.7393
# ***************************************
#
# ************** epoch: 19 **************
# loss_train: 0.5284, acc_train: 0.6935,
# recall_train: 0.9615, auc_train: 0.9156,
# loss_val: 0.6286, acc_val: 0.6452,
# recall_val: 0.5556, auc_val: 0.7479
# ***************************************
#
# ************** epoch: 20 **************
# loss_train: 0.4183, acc_train: 0.8548,
# recall_train: 0.8077, auc_train: 0.9135,
# loss_val: 0.7574, acc_val: 0.4516,
# recall_val: 0.0556, auc_val: 0.7564
# ***************************************
#
# ************** epoch: 21 **************
# loss_train: 0.4226, acc_train: 0.7419,
# recall_train: 0.4231, auc_train: 0.9466,
# loss_val: 0.5279, acc_val: 0.6774,
# recall_val: 0.7778, auc_val: 0.7991
# ***************************************
#
# ************** epoch: 22 **************
# loss_train: 0.3984, acc_train: 0.7258,
# recall_train: 0.8846, auc_train: 0.9391,
# loss_val: 0.5835, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8333
# ***************************************
#
# ************** epoch: 23 **************
# loss_train: 0.3007, acc_train: 0.9032,
# recall_train: 0.8846, auc_train: 0.9509,
# loss_val: 0.8531, acc_val: 0.6129,
# recall_val: 0.3889, auc_val: 0.7991
# ***************************************
#
# ************** epoch: 24 **************
# loss_train: 0.3208, acc_train: 0.8710,
# recall_train: 0.7692, auc_train: 0.9583,
# loss_val: 0.5146, acc_val: 0.7742,
# recall_val: 0.8889, auc_val: 0.8333
# ***************************************
#
# ************** epoch: 25 **************
# loss_train: 0.3730, acc_train: 0.8548,
# recall_train: 1.0000, auc_train: 0.9850,
# loss_val: 0.6442, acc_val: 0.6774,
# recall_val: 0.6111, auc_val: 0.8462
# ***************************************
#
# ************** epoch: 26 **************
# loss_train: 0.1880, acc_train: 0.9355,
# recall_train: 0.9615, auc_train: 0.9882,
# loss_val: 1.3853, acc_val: 0.5161,
# recall_val: 0.1667, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 27 **************
# loss_train: 0.3734, acc_train: 0.7903,
# recall_train: 0.5000, auc_train: 0.9915,
# loss_val: 0.5357, acc_val: 0.7742,
# recall_val: 0.9444, auc_val: 0.8761
# ***************************************
#
# ************** epoch: 28 **************
# loss_train: 0.5046, acc_train: 0.7903,
# recall_train: 1.0000, auc_train: 0.9808,
# loss_val: 0.4843, acc_val: 0.7742,
# recall_val: 0.8889, auc_val: 0.8761
# ***************************************
#
# ************** epoch: 29 **************
# loss_train: 0.3233, acc_train: 0.8548,
# recall_train: 1.0000, auc_train: 0.9915,
# loss_val: 1.3475, acc_val: 0.4839,
# recall_val: 0.1111, auc_val: 0.8462
# ***************************************
#
# ************** epoch: 30 **************
# loss_train: 0.3034, acc_train: 0.8387,
# recall_train: 0.6154, auc_train: 0.9850,
# loss_val: 0.9893, acc_val: 0.6452,
# recall_val: 0.3889, auc_val: 0.8675
# ***************************************
#
# ************** epoch: 31 **************
# loss_train: 0.1651, acc_train: 0.9677,
# recall_train: 0.9231, auc_train: 0.9947,
# loss_val: 0.5303, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.8675
# ***************************************
#
# ************** epoch: 32 **************
# loss_train: 0.2014, acc_train: 0.8548,
# recall_train: 0.9231, auc_train: 0.9829,
# loss_val: 0.4844, acc_val: 0.7419,
# recall_val: 0.7778, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 33 **************
# loss_train: 0.2369, acc_train: 0.8871,
# recall_train: 1.0000, auc_train: 0.9829,
# loss_val: 0.6332, acc_val: 0.7097,
# recall_val: 0.6111, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 34 **************
# loss_train: 0.1524, acc_train: 0.9194,
# recall_train: 0.9615, auc_train: 0.9893,
# loss_val: 1.1085, acc_val: 0.6129,
# recall_val: 0.3333, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 35 **************
# loss_train: 0.1538, acc_train: 0.9194,
# recall_train: 0.8077, auc_train: 0.9979,
# loss_val: 1.2419, acc_val: 0.6452,
# recall_val: 0.3889, auc_val: 0.8419
# ***************************************
#
# ************** epoch: 36 **************
# loss_train: 0.1663, acc_train: 0.9355,
# recall_train: 0.8462, auc_train: 0.9925,
# loss_val: 0.7897, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 37 **************
# loss_train: 0.1069, acc_train: 0.9516,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5955, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.8462
# ***************************************
#
# ************** epoch: 38 **************
# loss_train: 0.1268, acc_train: 0.9355,
# recall_train: 1.0000, auc_train: 0.9979,
# loss_val: 0.6500, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.8419
# ***************************************
#
# ************** epoch: 39 **************
# loss_train: 0.1050, acc_train: 0.9516,
# recall_train: 1.0000, auc_train: 0.9957,
# loss_val: 0.9494, acc_val: 0.6129,
# recall_val: 0.4444, auc_val: 0.8248
# ***************************************
#
# ************** epoch: 40 **************
# loss_train: 0.1403, acc_train: 0.9677,
# recall_train: 0.9615, auc_train: 0.9904,
# loss_val: 0.8868, acc_val: 0.6774,
# recall_val: 0.5556, auc_val: 0.8419
# ***************************************
#
# ************** epoch: 41 **************
# loss_train: 0.0689, acc_train: 0.9677,
# recall_train: 1.0000, auc_train: 0.9989,
# loss_val: 1.0754, acc_val: 0.6452,
# recall_val: 0.5000, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 42 **************
# loss_train: 0.0659, acc_train: 0.9677,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.3092, acc_val: 0.6774,
# recall_val: 0.5000, auc_val: 0.8419
# ***************************************
#
# ************** epoch: 43 **************
# loss_train: 0.0709, acc_train: 0.9839,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.3334, acc_val: 0.6774,
# recall_val: 0.5000, auc_val: 0.8504
# ***************************************
#
# ************** epoch: 44 **************
# loss_train: 0.0715, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.2366, acc_val: 0.7097,
# recall_val: 0.5000, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 45 **************
# loss_train: 0.0521, acc_train: 0.9839,
# recall_train: 0.9615, auc_train: 1.0000,
# loss_val: 1.0894, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 46 **************
# loss_train: 0.0509, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.1406, acc_val: 0.6774,
# recall_val: 0.5000, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 47 **************
# loss_train: 0.0429, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.3399, acc_val: 0.7097,
# recall_val: 0.5000, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 48 **************
# loss_train: 0.0353, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.4569, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 49 **************
# loss_train: 0.0288, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.5507, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 50 **************
# loss_train: 0.0279, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.5838, acc_val: 0.7419,
# recall_val: 0.5556, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 51 **************
# loss_train: 0.0237, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.4302, acc_val: 0.7419,
# recall_val: 0.5556, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 52 **************
# loss_train: 0.0168, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.3415, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8632
# ***************************************
#
# ************** epoch: 53 **************
# loss_train: 0.0172, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.4636, acc_val: 0.7419,
# recall_val: 0.5556, auc_val: 0.8675
# ***************************************
#
# ************** epoch: 54 **************
# loss_train: 0.0133, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.6365, acc_val: 0.7419,
# recall_val: 0.5556, auc_val: 0.8632
# ***************************************
#
# ************** epoch: 55 **************
# loss_train: 0.0088, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.8113, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 56 **************
# loss_train: 0.0080, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.9591, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 57 **************
# loss_train: 0.0086, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.9556, acc_val: 0.7419,
# recall_val: 0.5556, auc_val: 0.8632
# ***************************************
#
# ************** epoch: 58 **************
# loss_train: 0.0065, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.8403, acc_val: 0.7419,
# recall_val: 0.5556, auc_val: 0.8675
# ***************************************
#
# ************** epoch: 59 **************
# loss_train: 0.0048, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.7081, acc_val: 0.7742,
# recall_val: 0.6111, auc_val: 0.8718
# ***************************************
# Test set results: acc: 0.7376, f1_macro: 0.7332, f1_micro: 0.7376,precision: 0.8325, recall: 0.6190, auc: 0.8150, ap: 0.7915

# %% [markdown]
# ### 2.2. Vanilla GCNFN

# %%
run_model(GNNModelTypeEnum.VANILLA_GCNFN)
# Out:
# Loading data from directory: /home/sersery/Desktop/TUM_Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data
#
# ************** epoch: 0 **************
# loss_train: 0.6765, acc_train: 0.5484,
# recall_train: 0.1538, auc_train: 0.6357,
# loss_val: 2.2737, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6966
# ***************************************
#
# ************** epoch: 1 **************
# loss_train: 1.6454, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8504,
# loss_val: 1.0316, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.3675
# ***************************************
#
# ************** epoch: 2 **************
# loss_train: 1.3884, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.3622,
# loss_val: 4.3263, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4316
# ***************************************
#
# ************** epoch: 3 **************
# loss_train: 3.1236, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5556,
# loss_val: 0.9927, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6838
# ***************************************
#
# ************** epoch: 4 **************
# loss_train: 0.7831, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8472,
# loss_val: 0.9361, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.6966
# ***************************************
#
# ************** epoch: 5 **************
# loss_train: 1.2449, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.6528,
# loss_val: 0.6796, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 6 **************
# loss_train: 0.7233, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.6004,
# loss_val: 1.0958, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5940
# ***************************************
#
# ************** epoch: 7 **************
# loss_train: 0.8444, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6368,
# loss_val: 0.7199, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.7479
# ***************************************
#
# ************** epoch: 8 **************
# loss_train: 0.8701, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.7564,
# loss_val: 0.7630, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6410
# ***************************************
#
# ************** epoch: 9 **************
# loss_train: 0.6831, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7799,
# loss_val: 0.8175, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5256
# ***************************************
#
# ************** epoch: 10 **************
# loss_train: 0.6993, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7265,
# loss_val: 0.7513, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5812
# ***************************************
#
# ************** epoch: 11 **************
# loss_train: 0.6812, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7724,
# loss_val: 0.6944, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7607
# ***************************************
#
# ************** epoch: 12 **************
# loss_train: 0.6912, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8088,
# loss_val: 0.6952, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7906
# ***************************************
#
# ************** epoch: 13 **************
# loss_train: 0.6905, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8483,
# loss_val: 0.7490, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6624
# ***************************************
#
# ************** epoch: 14 **************
# loss_train: 0.6806, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8547,
# loss_val: 0.7975, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6111
# ***************************************
#
# ************** epoch: 15 **************
# loss_train: 0.6920, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8397,
# loss_val: 0.7583, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6795
# ***************************************
#
# ************** epoch: 16 **************
# loss_train: 0.6819, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8862,
# loss_val: 0.7039, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8889
# ***************************************
#
# ************** epoch: 17 **************
# loss_train: 0.6843, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9455,
# loss_val: 0.6806, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.9274
# ***************************************
#
# ************** epoch: 18 **************
# loss_train: 0.7144, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.9594,
# loss_val: 0.7408, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7564
# ***************************************
#
# ************** epoch: 19 **************
# loss_train: 0.6791, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9231,
# loss_val: 0.8372, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7009
# ***************************************
#
# ************** epoch: 20 **************
# loss_train: 0.7063, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8632,
# loss_val: 0.7653, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7607
# ***************************************
#
# ************** epoch: 21 **************
# loss_train: 0.6827, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9113,
# loss_val: 0.6881, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 22 **************
# loss_train: 0.6941, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.9263,
# loss_val: 0.6986, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 23 **************
# loss_train: 0.6862, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9444,
# loss_val: 0.7365, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 24 **************
# loss_train: 0.6790, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9284,
# loss_val: 0.7721, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8120
# ***************************************
#
# ************** epoch: 25 **************
# loss_train: 0.6845, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9145,
# loss_val: 0.7590, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8462
# ***************************************
#
# ************** epoch: 26 **************
# loss_train: 0.6816, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9231,
# loss_val: 0.7227, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.9188
# ***************************************
#
# ************** epoch: 27 **************
# loss_train: 0.6789, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9327,
# loss_val: 0.7056, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.9274
# ***************************************
#
# ************** epoch: 28 **************
# loss_train: 0.6827, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9423,
# loss_val: 0.7151, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.9145
# ***************************************
#
# ************** epoch: 29 **************
# loss_train: 0.6798, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9487,
# loss_val: 0.7437, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8889
# ***************************************
#
# ************** epoch: 30 **************
# loss_train: 0.6788, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9423,
# loss_val: 0.7571, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 31 **************
# loss_train: 0.6804, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9370,
# loss_val: 0.7415, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 32 **************
# loss_train: 0.6779, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9423,
# loss_val: 0.7175, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 33 **************
# loss_train: 0.6776, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9455,
# loss_val: 0.7083, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.9103
# ***************************************
#
# ************** epoch: 34 **************
# loss_train: 0.6782, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9530,
# loss_val: 0.7214, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 35 **************
# loss_train: 0.6754, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9541,
# loss_val: 0.7303, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.9017
# ***************************************
#
# ************** epoch: 36 **************
# loss_train: 0.6729, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9551,
# loss_val: 0.7033, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8974
# ***************************************
#
# ************** epoch: 37 **************
# loss_train: 0.6683, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9605,
# loss_val: 0.6964, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8932
# ***************************************
#
# ************** epoch: 38 **************
# loss_train: 0.6583, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9615,
# loss_val: 1.3602, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.8974
# ***************************************
#
# ************** epoch: 39 **************
# loss_train: 1.8597, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.9626,
# loss_val: 1.1233, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8205
# ***************************************
#
# ************** epoch: 40 **************
# loss_train: 0.8583, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9530,
# loss_val: 1.1138, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7521
# ***************************************
#
# ************** epoch: 41 **************
# loss_train: 0.8529, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9316,
# loss_val: 0.7653, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8376
# ***************************************
#
# ************** epoch: 42 **************
# loss_train: 0.6823, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9476,
# loss_val: 0.6839, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 43 **************
# loss_train: 0.7684, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.6603,
# loss_val: 0.6803, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.6795
# ***************************************
#
# ************** epoch: 44 **************
# loss_train: 0.7441, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.5246,
# loss_val: 0.6920, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 45 **************
# loss_train: 0.6942, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.7415,
# loss_val: 0.7040, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8846
# ***************************************
#
# ************** epoch: 46 **************
# loss_train: 0.6855, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9626,
# loss_val: 0.7081, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.1282
# ***************************************
#
# ************** epoch: 47 **************
# loss_train: 0.6842, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.1282,
# loss_val: 0.7196, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.2564
# ***************************************
#
# ************** epoch: 48 **************
# loss_train: 0.6812, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.3162,
# loss_val: 0.7396, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.2949
# ***************************************
#
# ************** epoch: 49 **************
# loss_train: 0.6804, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.4071,
# loss_val: 0.7817, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.1197
# ***************************************
#
# ************** epoch: 50 **************
# loss_train: 0.6895, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.0630,
# loss_val: 0.7414, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3590
# ***************************************
#
# ************** epoch: 51 **************
# loss_train: 0.6804, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5406,
# loss_val: 0.7268, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3675
# ***************************************
#
# ************** epoch: 52 **************
# loss_train: 0.6802, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5577,
# loss_val: 0.7194, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3803
# ***************************************
#
# ************** epoch: 53 **************
# loss_train: 0.6810, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6036,
# loss_val: 0.7162, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.2564
# ***************************************
#
# ************** epoch: 54 **************
# loss_train: 0.6817, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.3291,
# loss_val: 0.7158, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.2436
# ***************************************
#
# ************** epoch: 55 **************
# loss_train: 0.6818, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.3643,
# loss_val: 0.7258, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.1795
# ***************************************
#
# ************** epoch: 56 **************
# loss_train: 0.6833, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.0759,
# loss_val: 0.8936, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.2479
# ***************************************
#
# ************** epoch: 57 **************
# loss_train: 0.7331, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.1720,
# loss_val: 0.7105, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4188
# ***************************************
#
# ************** epoch: 58 **************
# loss_train: 0.6830, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6987,
# loss_val: 0.7059, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.2479
# ***************************************
#
# ************** epoch: 59 **************
# loss_train: 0.6850, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.2639,
# loss_val: 0.7133, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5513
# ***************************************
# Test set results: acc: 0.4887, f1_macro: 0.3280, f1_micro: 0.4887,precision: 0.0000, recall: 0.0000, auc: 0.6436, ap: 0.6244

# %% [markdown]
# # 3. Explain GNN

# %% [markdown]
# ### 3.1. GCN-GNN

# %%
run_model(GNNModelTypeEnum.GCN_GNN)
# Out:
# Loading data from directory: /home/sersery/Desktop/TUM_Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data
#
# ************** epoch: 0 **************
# loss_train: 0.9962, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.5107,
# loss_val: 11.6868, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3889
# ***************************************
#
# ************** epoch: 1 **************
# loss_train: 6.8702, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.4957,
# loss_val: 3.2701, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3761
# ***************************************
#
# ************** epoch: 2 **************
# loss_train: 1.9230, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5053,
# loss_val: 0.7408, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.5940
# ***************************************
#
# ************** epoch: 3 **************
# loss_train: 0.9346, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.4541,
# loss_val: 0.6758, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.6026
# ***************************************
#
# ************** epoch: 4 **************
# loss_train: 0.7917, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.4466,
# loss_val: 0.6926, acc_val: 0.4516,
# recall_val: 0.0556, auc_val: 0.6880
# ***************************************
#
# ************** epoch: 5 **************
# loss_train: 0.6860, acc_train: 0.5645,
# recall_train: 0.0385, auc_train: 0.5694,
# loss_val: 0.7604, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7479
# ***************************************
#
# ************** epoch: 6 **************
# loss_train: 0.6717, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7543,
# loss_val: 0.7833, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 7 **************
# loss_train: 0.6690, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8515,
# loss_val: 0.7380, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7991
# ***************************************
#
# ************** epoch: 8 **************
# loss_train: 0.6541, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9423,
# loss_val: 0.6997, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7607
# ***************************************
#
# ************** epoch: 9 **************
# loss_train: 0.6371, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9252,
# loss_val: 0.7072, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7607
# ***************************************
#
# ************** epoch: 10 **************
# loss_train: 0.6033, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9786,
# loss_val: 0.6348, acc_val: 0.6452,
# recall_val: 0.5556, auc_val: 0.7393
# ***************************************
#
# ************** epoch: 11 **************
# loss_train: 0.5574, acc_train: 0.8226,
# recall_train: 0.7308, auc_train: 0.9103,
# loss_val: 0.7181, acc_val: 0.4839,
# recall_val: 0.1111, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 12 **************
# loss_train: 0.5036, acc_train: 0.6774,
# recall_train: 0.2308, auc_train: 0.9872,
# loss_val: 0.5897, acc_val: 0.6774,
# recall_val: 0.7222, auc_val: 0.7308
# ***************************************
#
# ************** epoch: 13 **************
# loss_train: 0.4354, acc_train: 0.9194,
# recall_train: 0.9231, auc_train: 0.9840,
# loss_val: 0.6105, acc_val: 0.7097,
# recall_val: 0.6111, auc_val: 0.7991
# ***************************************
#
# ************** epoch: 14 **************
# loss_train: 0.3394, acc_train: 0.9194,
# recall_train: 0.8077, auc_train: 0.9936,
# loss_val: 0.5622, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.8120
# ***************************************
#
# ************** epoch: 15 **************
# loss_train: 0.2441, acc_train: 0.9677,
# recall_train: 0.9231, auc_train: 0.9968,
# loss_val: 0.5314, acc_val: 0.7419,
# recall_val: 0.8333, auc_val: 0.8291
# ***************************************
#
# ************** epoch: 16 **************
# loss_train: 0.1929, acc_train: 0.9516,
# recall_train: 1.0000, auc_train: 0.9957,
# loss_val: 1.2617, acc_val: 0.6129,
# recall_val: 0.3333, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 17 **************
# loss_train: 0.3948, acc_train: 0.7742,
# recall_train: 0.4615, auc_train: 1.0000,
# loss_val: 0.5350, acc_val: 0.7742,
# recall_val: 0.8889, auc_val: 0.8547
# ***************************************
#
# ************** epoch: 18 **************
# loss_train: 0.1102, acc_train: 0.9677,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.7284, acc_val: 0.7419,
# recall_val: 0.9444, auc_val: 0.8291
# ***************************************
#
# ************** epoch: 19 **************
# loss_train: 0.2778, acc_train: 0.8871,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6413, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.8675
# ***************************************
#
# ************** epoch: 20 **************
# loss_train: 0.0565, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.1907, acc_val: 0.7097,
# recall_val: 0.5000, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 21 **************
# loss_train: 0.1697, acc_train: 0.9355,
# recall_train: 0.8462, auc_train: 1.0000,
# loss_val: 0.9943, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8846
# ***************************************
#
# ************** epoch: 22 **************
# loss_train: 0.0963, acc_train: 0.9677,
# recall_train: 0.9231, auc_train: 1.0000,
# loss_val: 0.6632, acc_val: 0.8065,
# recall_val: 0.7778, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 23 **************
# loss_train: 0.0457, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5959, acc_val: 0.8065,
# recall_val: 0.8889, auc_val: 0.8632
# ***************************************
#
# ************** epoch: 24 **************
# loss_train: 0.0688, acc_train: 0.9839,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6451, acc_val: 0.8065,
# recall_val: 0.8889, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 25 **************
# loss_train: 0.0682, acc_train: 0.9839,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6967, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 26 **************
# loss_train: 0.0193, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.9292, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 27 **************
# loss_train: 0.0136, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.2220, acc_val: 0.7742,
# recall_val: 0.6667, auc_val: 0.8761
# ***************************************
#
# ************** epoch: 28 **************
# loss_train: 0.0220, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.3385, acc_val: 0.7742,
# recall_val: 0.6667, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 29 **************
# loss_train: 0.0251, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 1.1105, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 30 **************
# loss_train: 0.0073, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.8645, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 31 **************
# loss_train: 0.0029, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.7456, acc_val: 0.8387,
# recall_val: 0.8889, auc_val: 0.8675
# ***************************************
#
# ************** epoch: 32 **************
# loss_train: 0.0070, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.7535, acc_val: 0.8387,
# recall_val: 0.8889, auc_val: 0.8675
# ***************************************
#
# ************** epoch: 33 **************
# loss_train: 0.0082, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.7622, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8761
# ***************************************
#
# ************** epoch: 34 **************
# loss_train: 0.0036, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.8118, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8803
# ***************************************
# Test set results: acc: 0.8416, f1_macro: 0.8410, f1_micro: 0.8416,precision: 0.8739, recall: 0.8043, auc: 0.8922, ap: 0.8893

# %% [markdown]
# ### 3.2. SAGE-GNN

# %%
run_model(GNNModelTypeEnum.SAGE_GNN)
# Out:
# Loading data from directory: /home/sersery/Desktop/TUM_Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data
#
# ************** epoch: 0 **************
# loss_train: 0.7126, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.4038,
# loss_val: 3.6382, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7179
# ***************************************
#
# ************** epoch: 1 **************
# loss_train: 2.5710, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7842,
# loss_val: 0.7348, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 2 **************
# loss_train: 0.6380, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9530,
# loss_val: 0.6859, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.2564
# ***************************************
#
# ************** epoch: 3 **************
# loss_train: 0.7502, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.3098,
# loss_val: 0.6879, acc_val: 0.5806,
# recall_val: 0.8333, auc_val: 0.6923
# ***************************************
#
# ************** epoch: 4 **************
# loss_train: 0.6777, acc_train: 0.6774,
# recall_train: 0.9615, auc_train: 0.8942,
# loss_val: 0.8085, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7393
# ***************************************
#
# ************** epoch: 5 **************
# loss_train: 0.6776, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.8932,
# loss_val: 0.7437, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 6 **************
# loss_train: 0.6467, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9551,
# loss_val: 0.7036, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 7 **************
# loss_train: 0.6252, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9541,
# loss_val: 0.6908, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7692
# ***************************************
#
# ************** epoch: 8 **************
# loss_train: 0.5914, acc_train: 0.6290,
# recall_train: 0.1154, auc_train: 0.9605,
# loss_val: 0.6949, acc_val: 0.4839,
# recall_val: 0.1111, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 9 **************
# loss_train: 0.5394, acc_train: 0.6613,
# recall_train: 0.1923, auc_train: 0.9701,
# loss_val: 0.6555, acc_val: 0.6774,
# recall_val: 0.5000, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 10 **************
# loss_train: 0.4675, acc_train: 0.8065,
# recall_train: 0.5385, auc_train: 0.9765,
# loss_val: 0.6033, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 11 **************
# loss_train: 0.3824, acc_train: 0.9194,
# recall_train: 0.8846, auc_train: 0.9850,
# loss_val: 0.6592, acc_val: 0.7419,
# recall_val: 0.5556, auc_val: 0.8333
# ***************************************
#
# ************** epoch: 12 **************
# loss_train: 0.2977, acc_train: 0.8710,
# recall_train: 0.6923, auc_train: 0.9957,
# loss_val: 0.5795, acc_val: 0.7097,
# recall_val: 0.8889, auc_val: 0.8291
# ***************************************
#
# ************** epoch: 13 **************
# loss_train: 0.3189, acc_train: 0.8226,
# recall_train: 1.0000, auc_train: 0.9989,
# loss_val: 0.7344, acc_val: 0.7419,
# recall_val: 0.5556, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 14 **************
# loss_train: 0.1838, acc_train: 0.9355,
# recall_train: 0.8462, auc_train: 1.0000,
# loss_val: 0.7308, acc_val: 0.7742,
# recall_val: 0.6111, auc_val: 0.8761
# ***************************************
#
# ************** epoch: 15 **************
# loss_train: 0.1292, acc_train: 0.9516,
# recall_train: 0.8846, auc_train: 1.0000,
# loss_val: 0.5460, acc_val: 0.7742,
# recall_val: 0.8333, auc_val: 0.8761
# ***************************************
#
# ************** epoch: 16 **************
# loss_train: 0.1125, acc_train: 0.9677,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5576, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8974
# ***************************************
#
# ************** epoch: 17 **************
# loss_train: 0.0571, acc_train: 0.9839,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.8058, acc_val: 0.7742,
# recall_val: 0.6667, auc_val: 0.8932
# ***************************************
#
# ************** epoch: 18 **************
# loss_train: 0.0430, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.8627, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.8932
# ***************************************
#
# ************** epoch: 19 **************
# loss_train: 0.0317, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6587, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 20 **************
# loss_train: 0.0102, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6159, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8932
# ***************************************
#
# ************** epoch: 21 **************
# loss_train: 0.0198, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6587, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8932
# ***************************************
#
# ************** epoch: 22 **************
# loss_train: 0.0079, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.7746, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8846
# ***************************************
#
# ************** epoch: 23 **************
# loss_train: 0.0029, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.9353, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.8846
# ***************************************
#
# ************** epoch: 24 **************
# loss_train: 0.0050, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.9919, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 25 **************
# loss_train: 0.0066, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.8760, acc_val: 0.8387,
# recall_val: 0.7778, auc_val: 0.8846
# ***************************************
#
# ************** epoch: 26 **************
# loss_train: 0.0029, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.7514, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 27 **************
# loss_train: 0.0018, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6894, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 28 **************
# loss_train: 0.0039, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6633, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 29 **************
# loss_train: 0.0041, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6575, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8889
# ***************************************
#
# ************** epoch: 30 **************
# loss_train: 0.0023, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6985, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8932
# ***************************************
#
# ************** epoch: 31 **************
# loss_train: 0.0032, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6925, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8974
# ***************************************
#
# ************** epoch: 32 **************
# loss_train: 0.0052, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5572, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8932
# ***************************************
#
# ************** epoch: 33 **************
# loss_train: 0.0042, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.4763, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8974
# ***************************************
#
# ************** epoch: 34 **************
# loss_train: 0.0078, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.4803, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.8974
# ***************************************
# Test set results: acc: 0.8371, f1_macro: 0.8365, f1_micro: 0.8371,precision: 0.8654, recall: 0.8043, auc: 0.8937, ap: 0.8906

# %% [markdown]
# ### 3.3. GAT-GNN

# %%
run_model(GNNModelTypeEnum.GAT_GNN)
# Out:
# Loading data from directory: /home/sersery/Desktop/TUM_Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data
#
# ************** epoch: 0 **************
# loss_train: 0.6841, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.3857,
# loss_val: 0.6556, acc_val: 0.6452,
# recall_val: 0.8889, auc_val: 0.8162
# ***************************************
#
# ************** epoch: 1 **************
# loss_train: 0.6233, acc_train: 0.7581,
# recall_train: 1.0000, auc_train: 0.9626,
# loss_val: 3.6453, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 2 **************
# loss_train: 2.5087, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9017,
# loss_val: 0.8696, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7906
# ***************************************
#
# ************** epoch: 3 **************
# loss_train: 0.6093, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.9733,
# loss_val: 0.6755, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.7393
# ***************************************
#
# ************** epoch: 4 **************
# loss_train: 0.7176, acc_train: 0.4516,
# recall_train: 1.0000, auc_train: 0.9370,
# loss_val: 0.6774, acc_val: 0.5806,
# recall_val: 1.0000, auc_val: 0.7564
# ***************************************
#
# ************** epoch: 5 **************
# loss_train: 0.7214, acc_train: 0.4194,
# recall_train: 1.0000, auc_train: 0.9476,
# loss_val: 0.6446, acc_val: 0.6129,
# recall_val: 0.9444, auc_val: 0.8248
# ***************************************
#
# ************** epoch: 6 **************
# loss_train: 0.6400, acc_train: 0.5968,
# recall_train: 1.0000, auc_train: 0.9840,
# loss_val: 0.7150, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.8419
# ***************************************
#
# ************** epoch: 7 **************
# loss_train: 0.6438, acc_train: 0.5968,
# recall_train: 0.0385, auc_train: 0.9348,
# loss_val: 0.6797, acc_val: 0.4516,
# recall_val: 0.0556, auc_val: 0.8675
# ***************************************
#
# ************** epoch: 8 **************
# loss_train: 0.5938, acc_train: 0.6613,
# recall_train: 0.1923, auc_train: 0.9979,
# loss_val: 0.5886, acc_val: 0.7097,
# recall_val: 0.8889, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 9 **************
# loss_train: 0.5294, acc_train: 0.8387,
# recall_train: 1.0000, auc_train: 0.9979,
# loss_val: 0.5494, acc_val: 0.7419,
# recall_val: 0.7778, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 10 **************
# loss_train: 0.4245, acc_train: 0.9677,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6259, acc_val: 0.6774,
# recall_val: 0.4444, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 11 **************
# loss_train: 0.3500, acc_train: 0.8548,
# recall_train: 0.6538, auc_train: 1.0000,
# loss_val: 0.5244, acc_val: 0.7419,
# recall_val: 0.9444, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 12 **************
# loss_train: 0.3094, acc_train: 0.8226,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5021, acc_val: 0.7742,
# recall_val: 0.6667, auc_val: 0.8718
# ***************************************
#
# ************** epoch: 13 **************
# loss_train: 0.1616, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6396, acc_val: 0.7742,
# recall_val: 0.6111, auc_val: 0.8803
# ***************************************
#
# ************** epoch: 14 **************
# loss_train: 0.1576, acc_train: 0.9355,
# recall_train: 0.8462, auc_train: 1.0000,
# loss_val: 0.4973, acc_val: 0.8065,
# recall_val: 0.8889, auc_val: 0.8932
# ***************************************
#
# ************** epoch: 15 **************
# loss_train: 0.1197, acc_train: 0.9677,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.4677, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8974
# ***************************************
#
# ************** epoch: 16 **************
# loss_train: 0.0595, acc_train: 0.9839,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6658, acc_val: 0.8387,
# recall_val: 0.7222, auc_val: 0.9017
# ***************************************
#
# ************** epoch: 17 **************
# loss_train: 0.0581, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6077, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.9017
# ***************************************
#
# ************** epoch: 18 **************
# loss_train: 0.0282, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.4850, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.9103
# ***************************************
#
# ************** epoch: 19 **************
# loss_train: 0.0167, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5135, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.9188
# ***************************************
#
# ************** epoch: 20 **************
# loss_train: 0.0238, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5156, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9188
# ***************************************
#
# ************** epoch: 21 **************
# loss_train: 0.0066, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6142, acc_val: 0.8387,
# recall_val: 0.7778, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 22 **************
# loss_train: 0.0042, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.7459, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 23 **************
# loss_train: 0.0084, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.7284, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.9017
# ***************************************
#
# ************** epoch: 24 **************
# loss_train: 0.0064, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6237, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 25 **************
# loss_train: 0.0026, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5631, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9103
# ***************************************
#
# ************** epoch: 26 **************
# loss_train: 0.0024, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5678, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.9017
# ***************************************
#
# ************** epoch: 27 **************
# loss_train: 0.0054, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5632, acc_val: 0.8387,
# recall_val: 0.8333, auc_val: 0.8974
# ***************************************
#
# ************** epoch: 28 **************
# loss_train: 0.0059, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5416, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9017
# ***************************************
#
# ************** epoch: 29 **************
# loss_train: 0.0030, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5823, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 30 **************
# loss_train: 0.0036, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.6319, acc_val: 0.8387,
# recall_val: 0.7778, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 31 **************
# loss_train: 0.0067, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5498, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 32 **************
# loss_train: 0.0050, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.4695, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 33 **************
# loss_train: 0.0066, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.4549, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9060
# ***************************************
#
# ************** epoch: 34 **************
# loss_train: 0.0096, acc_train: 1.0000,
# recall_train: 1.0000, auc_train: 1.0000,
# loss_val: 0.5112, acc_val: 0.8710,
# recall_val: 0.8333, auc_val: 0.9060
# ***************************************
# Test set results: acc: 0.8100, f1_macro: 0.8083, f1_micro: 0.8100,precision: 0.8727, recall: 0.7328, auc: 0.8949, ap: 0.8910

# %% [markdown]
# # 4. GNNCL

# %%
run_model(GNNModelTypeEnum.GNNCL)
# Out:
# Loading data from directory: /home/sersery/Desktop/TUM_Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data
# /home/sersery/anaconda3/envs/gnnfakenews/lib/python3.9/site-packages/torch_geometric/data/dataset.py:150: UserWarning: The `pre_transform` argument differs from the one used in the pre-processed version of this dataset. If you want to make use of another pre-processing technique, make sure to sure to delete '/home/sersery/Desktop/TUM_Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data/politifact/processed/' first
#   warnings.warn(
# ************** epoch: 0 **************
# loss_train: 44.4060, acc_train: 0.4355,
# recall_train: 0.1538, auc_train: 0.3643,
# loss_val: 21.9276, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6239
# ***************************************
#
# ************** epoch: 1 **************
# loss_train: 42.3847, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.4690,
# loss_val: 22.0549, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5598
# ***************************************
#
# ************** epoch: 2 **************
# loss_train: 42.2845, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5288,
# loss_val: 22.2189, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4274
# ***************************************
#
# ************** epoch: 3 **************
# loss_train: 42.1819, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5256,
# loss_val: 22.4331, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3846
# ***************************************
#
# ************** epoch: 4 **************
# loss_train: 42.0944, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5353,
# loss_val: 22.6647, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3504
# ***************************************
#
# ************** epoch: 5 **************
# loss_train: 42.0223, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5705,
# loss_val: 22.8896, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3462
# ***************************************
#
# ************** epoch: 6 **************
# loss_train: 41.9690, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5994,
# loss_val: 23.1077, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3419
# ***************************************
#
# ************** epoch: 7 **************
# loss_train: 41.9354, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5940,
# loss_val: 23.2174, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3462
# ***************************************
#
# ************** epoch: 8 **************
# loss_train: 41.8950, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5855,
# loss_val: 23.2193, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4103
# ***************************************
#
# ************** epoch: 9 **************
# loss_train: 41.8375, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6111,
# loss_val: 23.1231, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4701
# ***************************************
#
# ************** epoch: 10 **************
# loss_train: 41.7701, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5876,
# loss_val: 22.9891, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4872
# ***************************************
#
# ************** epoch: 11 **************
# loss_train: 41.7020, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6111,
# loss_val: 22.8426, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4615
# ***************************************
#
# ************** epoch: 12 **************
# loss_train: 41.6267, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6100,
# loss_val: 22.7040, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4573
# ***************************************
#
# ************** epoch: 13 **************
# loss_train: 41.5365, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6154,
# loss_val: 22.6040, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4872
# ***************************************
#
# ************** epoch: 14 **************
# loss_train: 41.4257, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6261,
# loss_val: 22.5551, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5385
# ***************************************
#
# ************** epoch: 15 **************
# loss_train: 41.3025, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6410,
# loss_val: 22.5657, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5513
# ***************************************
#
# ************** epoch: 16 **************
# loss_train: 41.1721, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6528,
# loss_val: 22.4808, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5684
# ***************************************
#
# ************** epoch: 17 **************
# loss_train: 41.0131, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6506,
# loss_val: 22.2996, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5855
# ***************************************
#
# ************** epoch: 18 **************
# loss_train: 40.8246, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6560,
# loss_val: 22.3045, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5769
# ***************************************
#
# ************** epoch: 19 **************
# loss_train: 40.6011, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6709,
# loss_val: 22.2685, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6068
# ***************************************
#
# ************** epoch: 20 **************
# loss_train: 40.3207, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7137,
# loss_val: 21.8723, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.7009
# ***************************************
#
# ************** epoch: 21 **************
# loss_train: 39.9856, acc_train: 0.5968,
# recall_train: 0.0385, auc_train: 0.7692,
# loss_val: 22.4811, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6581
# ***************************************
#
# ************** epoch: 22 **************
# loss_train: 39.6654, acc_train: 0.5645,
# recall_train: 0.0385, auc_train: 0.7703,
# loss_val: 21.1274, acc_val: 0.5484,
# recall_val: 0.2222, auc_val: 0.7863
# ***************************************
#
# ************** epoch: 23 **************
# loss_train: 39.3401, acc_train: 0.6613,
# recall_train: 0.2692, auc_train: 0.7724,
# loss_val: 22.4482, acc_val: 0.5484,
# recall_val: 0.2222, auc_val: 0.6667
# ***************************************
#
# ************** epoch: 24 **************
# loss_train: 38.7899, acc_train: 0.5968,
# recall_train: 0.1154, auc_train: 0.8184,
# loss_val: 21.3212, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 25 **************
# loss_train: 38.2076, acc_train: 0.6774,
# recall_train: 0.3077, auc_train: 0.8088,
# loss_val: 22.4915, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.7009
# ***************************************
#
# ************** epoch: 26 **************
# loss_train: 37.5563, acc_train: 0.6452,
# recall_train: 0.2308, auc_train: 0.8184,
# loss_val: 20.7015, acc_val: 0.6129,
# recall_val: 0.3889, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 27 **************
# loss_train: 37.0617, acc_train: 0.6774,
# recall_train: 0.3462, auc_train: 0.8088,
# loss_val: 29.2320, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6282
# ***************************************
#
# ************** epoch: 28 **************
# loss_train: 37.5734, acc_train: 0.6290,
# recall_train: 0.1923, auc_train: 0.7457,
# loss_val: 19.2712, acc_val: 0.6774,
# recall_val: 0.5556, auc_val: 0.8120
# ***************************************
#
# ************** epoch: 29 **************
# loss_train: 38.0426, acc_train: 0.6774,
# recall_train: 0.4231, auc_train: 0.7628,
# loss_val: 19.3666, acc_val: 0.6452,
# recall_val: 0.5000, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 30 **************
# loss_train: 38.3095, acc_train: 0.6774,
# recall_train: 0.4231, auc_train: 0.7436,
# loss_val: 21.4212, acc_val: 0.6452,
# recall_val: 0.4444, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 31 **************
# loss_train: 35.3614, acc_train: 0.6774,
# recall_train: 0.3462, auc_train: 0.7970,
# loss_val: 40.0385, acc_val: 0.5161,
# recall_val: 0.2222, auc_val: 0.5769
# ***************************************
#
# ************** epoch: 32 **************
# loss_train: 39.3256, acc_train: 0.5968,
# recall_train: 0.1154, auc_train: 0.7447,
# loss_val: 20.8141, acc_val: 0.6452,
# recall_val: 0.4444, auc_val: 0.8419
# ***************************************
#
# ************** epoch: 33 **************
# loss_train: 34.8247, acc_train: 0.6935,
# recall_train: 0.3846, auc_train: 0.8066,
# loss_val: 19.4874, acc_val: 0.7097,
# recall_val: 0.6667, auc_val: 0.8120
# ***************************************
#
# ************** epoch: 34 **************
# loss_train: 37.8649, acc_train: 0.6613,
# recall_train: 0.4615, auc_train: 0.7650,
# loss_val: 19.5291, acc_val: 0.7419,
# recall_val: 0.7222, auc_val: 0.8162
# ***************************************
#
# ************** epoch: 35 **************
# loss_train: 37.6754, acc_train: 0.6452,
# recall_train: 0.5000, auc_train: 0.7650,
# loss_val: 20.3912, acc_val: 0.6774,
# recall_val: 0.5000, auc_val: 0.8504
# ***************************************
#
# ************** epoch: 36 **************
# loss_train: 34.4313, acc_train: 0.6935,
# recall_train: 0.4231, auc_train: 0.8024,
# loss_val: 29.3724, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6453
# ***************************************
#
# ************** epoch: 37 **************
# loss_train: 33.9302, acc_train: 0.6774,
# recall_train: 0.3077, auc_train: 0.8387,
# loss_val: 39.4319, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6068
# ***************************************
#
# ************** epoch: 38 **************
# loss_train: 36.5294, acc_train: 0.6129,
# recall_train: 0.1538, auc_train: 0.7938,
# loss_val: 25.4477, acc_val: 0.5806,
# recall_val: 0.3333, auc_val: 0.7179
# ***************************************
#
# ************** epoch: 39 **************
# loss_train: 32.9013, acc_train: 0.7258,
# recall_train: 0.4231, auc_train: 0.8376,
# loss_val: 20.5217, acc_val: 0.8065,
# recall_val: 0.7222, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 40 **************
# loss_train: 33.6785, acc_train: 0.7258,
# recall_train: 0.6154, auc_train: 0.8152,
# loss_val: 20.0985, acc_val: 0.8065,
# recall_val: 0.7778, auc_val: 0.8462
# ***************************************
#
# ************** epoch: 41 **************
# loss_train: 34.3518, acc_train: 0.7258,
# recall_train: 0.6538, auc_train: 0.8323,
# loss_val: 20.6207, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8846
# ***************************************
#
# ************** epoch: 42 **************
# loss_train: 32.7508, acc_train: 0.7258,
# recall_train: 0.5000, auc_train: 0.8301,
# loss_val: 23.6603, acc_val: 0.6452,
# recall_val: 0.4444, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 43 **************
# loss_train: 32.3478, acc_train: 0.7097,
# recall_train: 0.4231, auc_train: 0.8301,
# loss_val: 29.9327, acc_val: 0.5806,
# recall_val: 0.3333, auc_val: 0.6752
# ***************************************
#
# ************** epoch: 44 **************
# loss_train: 32.0174, acc_train: 0.7097,
# recall_train: 0.3846, auc_train: 0.8451,
# loss_val: 35.3030, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6709
# ***************************************
#
# ************** epoch: 45 **************
# loss_train: 30.6848, acc_train: 0.7581,
# recall_train: 0.5385, auc_train: 0.8558,
# loss_val: 31.1060, acc_val: 0.7097,
# recall_val: 0.6111, auc_val: 0.7222
# ***************************************
#
# ************** epoch: 46 **************
# loss_train: 30.6956, acc_train: 0.7742,
# recall_train: 0.8846, auc_train: 0.8643,
# loss_val: 28.9538, acc_val: 0.7742,
# recall_val: 0.7222, auc_val: 0.7692
# ***************************************
#
# ************** epoch: 47 **************
# loss_train: 30.6593, acc_train: 0.7903,
# recall_train: 0.9615, auc_train: 0.8782,
# loss_val: 32.4943, acc_val: 0.7419,
# recall_val: 0.6111, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 48 **************
# loss_train: 28.6693, acc_train: 0.7903,
# recall_train: 0.7308, auc_train: 0.8729,
# loss_val: 40.2531, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.7009
# ***************************************
#
# ************** epoch: 49 **************
# loss_train: 28.8951, acc_train: 0.7581,
# recall_train: 0.5000, auc_train: 0.8718,
# loss_val: 32.6400, acc_val: 0.6129,
# recall_val: 0.3889, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 50 **************
# loss_train: 28.3584, acc_train: 0.7742,
# recall_train: 0.5385, auc_train: 0.8739,
# loss_val: 28.0910, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.8205
# ***************************************
#
# ************** epoch: 51 **************
# loss_train: 27.4783, acc_train: 0.7903,
# recall_train: 0.6923, auc_train: 0.8750,
# loss_val: 47.4281, acc_val: 0.7419,
# recall_val: 0.6111, auc_val: 0.7393
# ***************************************
#
# ************** epoch: 52 **************
# loss_train: 27.0513, acc_train: 0.7581,
# recall_train: 0.7308, auc_train: 0.8857,
# loss_val: 71.0182, acc_val: 0.7419,
# recall_val: 0.6111, auc_val: 0.7308
# ***************************************
#
# ************** epoch: 53 **************
# loss_train: 27.3069, acc_train: 0.7742,
# recall_train: 0.7308, auc_train: 0.8771,
# loss_val: 27.2872, acc_val: 0.8387,
# recall_val: 0.7778, auc_val: 0.8632
# ***************************************
#
# ************** epoch: 54 **************
# loss_train: 26.7694, acc_train: 0.7903,
# recall_train: 0.7308, auc_train: 0.8707,
# loss_val: 32.7270, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.7991
# ***************************************
#
# ************** epoch: 55 **************
# loss_train: 26.4214, acc_train: 0.8226,
# recall_train: 0.7308, auc_train: 0.8846,
# loss_val: 58.4633, acc_val: 0.6452,
# recall_val: 0.4444, auc_val: 0.7137
# ***************************************
#
# ************** epoch: 56 **************
# loss_train: 24.8734, acc_train: 0.8387,
# recall_train: 0.7308, auc_train: 0.8974,
# loss_val: 72.4863, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.7265
# ***************************************
#
# ************** epoch: 57 **************
# loss_train: 25.7800, acc_train: 0.8065,
# recall_train: 0.9231, auc_train: 0.8953,
# loss_val: 58.2367, acc_val: 0.7419,
# recall_val: 0.6111, auc_val: 0.7393
# ***************************************
#
# ************** epoch: 58 **************
# loss_train: 24.5655, acc_train: 0.7903,
# recall_train: 0.8077, auc_train: 0.9124,
# loss_val: 56.0076, acc_val: 0.6452,
# recall_val: 0.4444, auc_val: 0.7692
# ***************************************
#
# ************** epoch: 59 **************
# loss_train: 24.3712, acc_train: 0.8226,
# recall_train: 0.7308, auc_train: 0.9028,
# loss_val: 45.2844, acc_val: 0.6774,
# recall_val: 0.5000, auc_val: 0.7991
# ***************************************
# Test set results: acc: 0.6833, f1_macro: 0.6760, f1_micro: 0.6833,precision: 0.7732, recall: 0.5382, auc: 0.7186, ap: 0.6884
