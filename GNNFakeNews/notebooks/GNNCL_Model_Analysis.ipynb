# %%
"""
helper file to handle GNNCL model implementation in https://github.com/safe-graph/GNN-FakeNews
"""

# %%
% load_ext autoreload
% autoreload

# %%
from GNNFakeNews.utils.helpers import GNNModelTypeEnum
from utils import run_model

# %%
model = run_model(GNNModelTypeEnum.GNNCL)
# Out:
# Loading data from directory: /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data
# The `pre_transform` argument differs from the one used in the pre-processed version of this dataset. If you want to make use of another pre-processing technique, make sure to sure to delete '/home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/data/politifact/processed/' first
# ************** epoch: 0 **************
# loss_train: 44.4059, acc_train: 0.4355,
# recall_train: 0.1538, auc_train: 0.3643,
# loss_val: 21.9277, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6239
# ***************************************
#
# ************** epoch: 1 **************
# loss_train: 42.3848, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.4690,
# loss_val: 22.0555, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5598
# ***************************************
#
# ************** epoch: 2 **************
# loss_train: 42.2842, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5310,
# loss_val: 22.2178, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4274
# ***************************************
#
# ************** epoch: 3 **************
# loss_train: 42.1813, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5246,
# loss_val: 22.4378, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3846
# ***************************************
#
# ************** epoch: 4 **************
# loss_train: 42.0940, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5321,
# loss_val: 22.6570, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3547
# ***************************************
#
# ************** epoch: 5 **************
# loss_train: 42.0192, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5726,
# loss_val: 22.8787, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3547
# ***************************************
#
# ************** epoch: 6 **************
# loss_train: 41.9652, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5951,
# loss_val: 23.0959, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3419
# ***************************************
#
# ************** epoch: 7 **************
# loss_train: 41.9309, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6122,
# loss_val: 23.2193, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3547
# ***************************************
#
# ************** epoch: 8 **************
# loss_train: 41.8957, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5897,
# loss_val: 23.2156, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.3932
# ***************************************
#
# ************** epoch: 9 **************
# loss_train: 41.8477, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6197,
# loss_val: 23.1276, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4487
# ***************************************
#
# ************** epoch: 10 **************
# loss_train: 41.7871, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5983,
# loss_val: 23.0044, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4872
# ***************************************
#
# ************** epoch: 11 **************
# loss_train: 41.7163, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.5908,
# loss_val: 22.8729, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4829
# ***************************************
#
# ************** epoch: 12 **************
# loss_train: 41.6318, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6207,
# loss_val: 22.7654, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4701
# ***************************************
#
# ************** epoch: 13 **************
# loss_train: 41.5298, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6314,
# loss_val: 22.7218, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.4658
# ***************************************
#
# ************** epoch: 14 **************
# loss_train: 41.4207, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6517,
# loss_val: 22.7589, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5000
# ***************************************
#
# ************** epoch: 15 **************
# loss_train: 41.3062, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6795,
# loss_val: 22.7666, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5598
# ***************************************
#
# ************** epoch: 16 **************
# loss_train: 41.1705, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7105,
# loss_val: 22.6306, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.5855
# ***************************************
#
# ************** epoch: 17 **************
# loss_train: 40.9997, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7233,
# loss_val: 22.2327, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6026
# ***************************************
#
# ************** epoch: 18 **************
# loss_train: 40.8029, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6752,
# loss_val: 22.1782, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6197
# ***************************************
#
# ************** epoch: 19 **************
# loss_train: 40.5615, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.6923,
# loss_val: 22.3384, acc_val: 0.4194,
# recall_val: 0.0000, auc_val: 0.6154
# ***************************************
#
# ************** epoch: 20 **************
# loss_train: 40.3032, acc_train: 0.5806,
# recall_train: 0.0000, auc_train: 0.7350,
# loss_val: 21.7608, acc_val: 0.4516,
# recall_val: 0.0556, auc_val: 0.7009
# ***************************************
#
# ************** epoch: 21 **************
# loss_train: 39.9598, acc_train: 0.5806,
# recall_train: 0.0385, auc_train: 0.7821,
# loss_val: 21.9735, acc_val: 0.4839,
# recall_val: 0.1111, auc_val: 0.7179
# ***************************************
#
# ************** epoch: 22 **************
# loss_train: 39.5470, acc_train: 0.5645,
# recall_train: 0.0385, auc_train: 0.8120,
# loss_val: 21.7054, acc_val: 0.5161,
# recall_val: 0.1667, auc_val: 0.7350
# ***************************************
#
# ************** epoch: 23 **************
# loss_train: 39.0598, acc_train: 0.5968,
# recall_train: 0.1154, auc_train: 0.8184,
# loss_val: 22.5573, acc_val: 0.5484,
# recall_val: 0.2222, auc_val: 0.6667
# ***************************************
#
# ************** epoch: 24 **************
# loss_train: 38.6015, acc_train: 0.6129,
# recall_train: 0.1538, auc_train: 0.8194,
# loss_val: 20.4194, acc_val: 0.6452,
# recall_val: 0.4444, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 25 **************
# loss_train: 38.8103, acc_train: 0.6613,
# recall_train: 0.3077, auc_train: 0.7799,
# loss_val: 23.2468, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6496
# ***************************************
#
# ************** epoch: 26 **************
# loss_train: 37.5117, acc_train: 0.6290,
# recall_train: 0.1923, auc_train: 0.8120,
# loss_val: 23.7000, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6538
# ***************************************
#
# ************** epoch: 27 **************
# loss_train: 36.8478, acc_train: 0.6452,
# recall_train: 0.2308, auc_train: 0.8162,
# loss_val: 20.0227, acc_val: 0.6774,
# recall_val: 0.5000, auc_val: 0.8419
# ***************************************
#
# ************** epoch: 28 **************
# loss_train: 36.9353, acc_train: 0.6935,
# recall_train: 0.3846, auc_train: 0.8002,
# loss_val: 25.5758, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6752
# ***************************************
#
# ************** epoch: 29 **************
# loss_train: 35.3305, acc_train: 0.6774,
# recall_train: 0.3077, auc_train: 0.8205,
# loss_val: 31.6012, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6667
# ***************************************
#
# ************** epoch: 30 **************
# loss_train: 34.8065, acc_train: 0.6613,
# recall_train: 0.2692, auc_train: 0.8216,
# loss_val: 19.3911, acc_val: 0.7419,
# recall_val: 0.6667, auc_val: 0.8205
# ***************************************
#
# ************** epoch: 31 **************
# loss_train: 37.0413, acc_train: 0.6935,
# recall_train: 0.4615, auc_train: 0.7970,
# loss_val: 29.7865, acc_val: 0.5806,
# recall_val: 0.3333, auc_val: 0.7051
# ***************************************
#
# ************** epoch: 32 **************
# loss_train: 33.2888, acc_train: 0.7258,
# recall_train: 0.4231, auc_train: 0.8173,
# loss_val: 82.0696, acc_val: 0.5484,
# recall_val: 0.2778, auc_val: 0.6026
# ***************************************
#
# ************** epoch: 33 **************
# loss_train: 47.9238, acc_train: 0.6129,
# recall_train: 0.1538, auc_train: 0.6976,
# loss_val: 20.6467, acc_val: 0.7097,
# recall_val: 0.6667, auc_val: 0.8034
# ***************************************
#
# ************** epoch: 34 **************
# loss_train: 38.9913, acc_train: 0.6613,
# recall_train: 0.5000, auc_train: 0.7639,
# loss_val: 18.5827, acc_val: 0.6774,
# recall_val: 0.7222, auc_val: 0.7564
# ***************************************
#
# ************** epoch: 35 **************
# loss_train: 48.1931, acc_train: 0.5806,
# recall_train: 0.5000, auc_train: 0.6774,
# loss_val: 21.0375, acc_val: 0.6774,
# recall_val: 0.7778, auc_val: 0.7179
# ***************************************
#
# ************** epoch: 36 **************
# loss_train: 44.2828, acc_train: 0.5806,
# recall_train: 0.5000, auc_train: 0.6677,
# loss_val: 20.1188, acc_val: 0.6774,
# recall_val: 0.7222, auc_val: 0.7179
# ***************************************
#
# ************** epoch: 37 **************
# loss_train: 43.2328, acc_train: 0.5806,
# recall_train: 0.5000, auc_train: 0.6357,
# loss_val: 20.0959, acc_val: 0.6774,
# recall_val: 0.7222, auc_val: 0.6496
# ***************************************
#
# ************** epoch: 38 **************
# loss_train: 40.5034, acc_train: 0.6290,
# recall_train: 0.5000, auc_train: 0.6506,
# loss_val: 20.7986, acc_val: 0.6129,
# recall_val: 0.5000, auc_val: 0.7009
# ***************************************
#
# ************** epoch: 39 **************
# loss_train: 39.4046, acc_train: 0.6129,
# recall_train: 0.3077, auc_train: 0.7105,
# loss_val: 21.7831, acc_val: 0.4839,
# recall_val: 0.1667, auc_val: 0.7051
# ***************************************
#
# ************** epoch: 40 **************
# loss_train: 39.2372, acc_train: 0.6290,
# recall_train: 0.1923, auc_train: 0.7244,
# loss_val: 22.3640, acc_val: 0.4839,
# recall_val: 0.1667, auc_val: 0.7009
# ***************************************
#
# ************** epoch: 41 **************
# loss_train: 39.0260, acc_train: 0.6290,
# recall_train: 0.1154, auc_train: 0.7318,
# loss_val: 22.5050, acc_val: 0.4516,
# recall_val: 0.1111, auc_val: 0.7479
# ***************************************
#
# ************** epoch: 42 **************
# loss_train: 38.3954, acc_train: 0.6129,
# recall_train: 0.0769, auc_train: 0.7714,
# loss_val: 22.3866, acc_val: 0.4516,
# recall_val: 0.1111, auc_val: 0.7778
# ***************************************
#
# ************** epoch: 43 **************
# loss_train: 37.7577, acc_train: 0.6129,
# recall_train: 0.0769, auc_train: 0.7895,
# loss_val: 22.3240, acc_val: 0.4839,
# recall_val: 0.1667, auc_val: 0.7094
# ***************************************
#
# ************** epoch: 44 **************
# loss_train: 37.6598, acc_train: 0.6129,
# recall_train: 0.0769, auc_train: 0.8248,
# loss_val: 22.5332, acc_val: 0.4839,
# recall_val: 0.1667, auc_val: 0.6410
# ***************************************
#
# ************** epoch: 45 **************
# loss_train: 37.4752, acc_train: 0.6613,
# recall_train: 0.1923, auc_train: 0.8226,
# loss_val: 23.0346, acc_val: 0.4839,
# recall_val: 0.1667, auc_val: 0.6496
# ***************************************
#
# ************** epoch: 46 **************
# loss_train: 36.7941, acc_train: 0.6613,
# recall_train: 0.1923, auc_train: 0.8226,
# loss_val: 23.9439, acc_val: 0.4839,
# recall_val: 0.1667, auc_val: 0.6923
# ***************************************
#
# ************** epoch: 47 **************
# loss_train: 36.2538, acc_train: 0.6613,
# recall_train: 0.1923, auc_train: 0.8109,
# loss_val: 24.8435, acc_val: 0.4839,
# recall_val: 0.1667, auc_val: 0.6923
# ***************************************
#
# ************** epoch: 48 **************
# loss_train: 36.1278, acc_train: 0.6290,
# recall_train: 0.1538, auc_train: 0.7959,
# loss_val: 24.6875, acc_val: 0.4839,
# recall_val: 0.1667, auc_val: 0.7009
# ***************************************
#
# ************** epoch: 49 **************
# loss_train: 35.5486, acc_train: 0.6774,
# recall_train: 0.3077, auc_train: 0.8024,
# loss_val: 23.5569, acc_val: 0.6452,
# recall_val: 0.4444, auc_val: 0.7308
# ***************************************
#
# ************** epoch: 50 **************
# loss_train: 34.7117, acc_train: 0.7581,
# recall_train: 0.5385, auc_train: 0.8323,
# loss_val: 22.5519, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.7350
# ***************************************
#
# ************** epoch: 51 **************
# loss_train: 34.4767, acc_train: 0.7581,
# recall_train: 0.6538, auc_train: 0.8504,
# loss_val: 22.2751, acc_val: 0.7097,
# recall_val: 0.6111, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 52 **************
# loss_train: 33.8160, acc_train: 0.7419,
# recall_train: 0.6538, auc_train: 0.8462,
# loss_val: 22.8227, acc_val: 0.6774,
# recall_val: 0.5000, auc_val: 0.7650
# ***************************************
#
# ************** epoch: 53 **************
# loss_train: 33.0057, acc_train: 0.7903,
# recall_train: 0.6538, auc_train: 0.8344,
# loss_val: 23.5028, acc_val: 0.6129,
# recall_val: 0.3889, auc_val: 0.7821
# ***************************************
#
# ************** epoch: 54 **************
# loss_train: 32.6788, acc_train: 0.7419,
# recall_train: 0.5385, auc_train: 0.8312,
# loss_val: 22.4448, acc_val: 0.6452,
# recall_val: 0.4444, auc_val: 0.8291
# ***************************************
#
# ************** epoch: 55 **************
# loss_train: 31.6608, acc_train: 0.7903,
# recall_train: 0.6538, auc_train: 0.8440,
# loss_val: 21.4274, acc_val: 0.7419,
# recall_val: 0.6111, auc_val: 0.8590
# ***************************************
#
# ************** epoch: 56 **************
# loss_train: 31.1243, acc_train: 0.7903,
# recall_train: 0.6923, auc_train: 0.8579,
# loss_val: 22.0557, acc_val: 0.7419,
# recall_val: 0.6111, auc_val: 0.8248
# ***************************************
#
# ************** epoch: 57 **************
# loss_train: 30.3903, acc_train: 0.7903,
# recall_train: 0.6923, auc_train: 0.8590,
# loss_val: 23.8181, acc_val: 0.7097,
# recall_val: 0.5556, auc_val: 0.7949
# ***************************************
#
# ************** epoch: 58 **************
# loss_train: 29.8735, acc_train: 0.7903,
# recall_train: 0.6538, auc_train: 0.8579,
# loss_val: 22.4483, acc_val: 0.7742,
# recall_val: 0.6667, auc_val: 0.8419
# ***************************************
#
# ************** epoch: 59 **************
# loss_train: 29.0310, acc_train: 0.7903,
# recall_train: 0.6923, auc_train: 0.8579,
# loss_val: 20.7069, acc_val: 0.8387,
# recall_val: 0.7778, auc_val: 0.8803
# ***************************************
# Test set results: acc: 0.7421, f1_macro: 0.7407, f1_micro: 0.7421,precision: 0.7691, recall: 0.7070, auc: 0.8140, ap: 0.7658
