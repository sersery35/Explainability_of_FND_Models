# %%
# %load_ext autoreload
# %autoreload 2

# %%
from GNNFakeNews.utils.helpers import GNNModelTypeEnum
from util import run_model, GNNModelExplainer
from GNNFakeNews.utils.helpers import HparamFactory
from GNNFakeNews.utils.enums import GNNDatasetTypeEnum

# %%
model_type = GNNModelTypeEnum.GAT_GNN

# %%
gat_model_politifact_bert, dataset_manager_politifact_bert = run_model(model_type, return_dataset_manager=True, local_load=True)

sample_data = dataset_manager_politifact_bert.get_train_samples()[0].to(gat_model_politifact_bert.m_args.device)

gat_model_politifact_explainer = GNNModelExplainer(gat_model_politifact_bert, sample_data)
# Out:
# #################################
# -----> The hyperparameters are set!
# model_type = GNNModelTypeEnum.GAT_GNN
# dataset = GNNDatasetTypeEnum.POLITIFACT
# batch_size = 128
# lr = 0.01
# weight_decay = 0.01
# n_hidden = 128
# epochs = 35
# feature = GNNFeatureTypeEnum.BERT
# concat = True
# transform = <GNNFakeNews.utils.data_loader.ToUndirected object at 0x7f915fee3990>
# #################################
# Loading dataset 'politifact' from directory: /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/GNNFakeNews/data/local
# Test set results: acc: 0.8145, f1_macro: 0.8124, f1_micro: 0.8145,precision: 0.8899, recall: 0.7235, auc: 0.8954, ap: 0.8906
# Explain graph: 100%|██████████| 200/200 [00:00<00:00, 226.27it/s]
